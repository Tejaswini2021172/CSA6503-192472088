# %% [markdown]
# # Text Generation

# %%
from groq import Groq

client = Groq(api_key="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")

#prompt = input("WRITE A THREE LINE OF STORY ABOUT GOOD BEHAVIOUR ")

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[{"role": "user", "content": "WRITE A THREE LINE OF STORY ABOUT GOOD BEHAVIOUR"}]
)

print("\nGenerated Text:")
print(response.choices[0].message.content)
# Out:
# Generated Text:
# As she walked into the classroom, Emma's good behaviour was evident in the way she respectfully greeted her teacher and quietly took her seat. Her classmates noticed her kindness and consideration towards others, and soon they were all inspired to follow her example. By the end of the day, the entire class was filled with a sense of harmony and friendship, all thanks to Emma's positive influence.

# %% [markdown]
# # Text Summarization

# %%
from groq import Groq

client = Groq(api_key="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")

text = """
Artificial Intelligence (AI) is one of the most important technologies in the modern world.
It allows computers and machines to perform tasks that normally require human intelligence,
such as learning, reasoning, problem-solving, understanding language, and recognizing images.
AI is being used in many different industries. In healthcare, it helps doctors detect diseases,
analyze medical images, and discover new medicines. In education, AI can provide personalized
learning experiences and intelligent tutoring systems. In banking, it is used to detect fraud,
analyze transactions, and improve customer service. In transportation, AI supports navigation,
traffic prediction, and autonomous driving systems. Machine Learning is a major part of AI
where computers learn patterns from data without being explicitly programmed for every task.
Deep Learning is a further development that uses neural networks with many layers to solve
complex problems involving images, speech, and natural language. As AI continues to develop,
it is expected to create new opportunities while also requiring responsible and ethical use.
"""

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": f"Summarize the following text in exactly 2 or 3 short sentences:\n\n{text}"
        }
    ]
)

print("Original Text:")
print(text)

print("\nSummary:")
print(response.choices[0].message.content)
# Out:
# Original Text:
#
# Artificial Intelligence (AI) is one of the most important technologies in the modern world.
# It allows computers and machines to perform tasks that normally require human intelligence,
# such as learning, reasoning, problem-solving, understanding language, and recognizing images.
# AI is being used in many different industries. In healthcare, it helps doctors detect diseases,
# analyze medical images, and discover new medicines. In education, AI can provide personalized
# learning experiences and intelligent tutoring systems. In banking, it is used to detect fraud,
# analyze transactions, and improve customer service. In transportation, AI supports navigation,
# traffic prediction, and autonomous driving systems. Machine Learning is a major part of AI
# where computers learn patterns from data without being explicitly programmed for every task.
# Deep Learning is a further development that uses neural networks with many layers to solve
# complex problems involving images, speech, and natural language. As AI continues to develop,
# it is expected to create new opportunities while also requiring responsible and ethical use.
#
#
# Summary:
# Artificial Intelligence (AI) enables computers to perform human-like tasks, such as learning and problem-solving, and is being used in various industries like healthcare, education, and banking. AI is applied in these fields to improve services, detect issues, and enhance customer experiences. It continues to develop, with techniques like Machine Learning and Deep Learning, and is expected to create new opportunities with responsible use.

# %%
from groq import Groq
from pypdf import PdfReader

client = Groq(api_key="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")

pdf_path = r"C:\Users\tejv3\Downloads\Generative AI and LLMs - Comprehensive Guide.pdf"

reader = PdfReader(pdf_path)

text = ""

for page in reader.pages:
    page_text = page.extract_text()
    if page_text:
        text += page_text + "\n"

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": f"Summarize the following PDF in exactly 2 or 3 short sentences:\n\n{text}"
        }
    ]
)

print("\nSummary:")
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       4 client = Groq(api_key="YOUR_GROQ_API_KEY")
#       5
#       6 pdf_path = input("Enter PDF file path: ")
#       7
# ----> 8 reader = PdfReader(pdf_path)
#       9
#      10 text = ""
#      11
#
# File ~\OneDrive\Desktop\LAB-GEN AI\.venv\Lib\site-packages\pypdf\_reader.py:151, in PdfReader.__init__(self, stream, strict, password, root_object_recovery_limit)
#     147 self._page_id2num: Optional[dict[Any, Any]] = None
#     149 self._validated_root: Optional[DictionaryObject] = None
# --> 151 self._initialize_stream(stream)
#     152 self._known_objects: set[tuple[int, int]] = set()
#     154 self._override_encryption = False
#
# File ~\OneDrive\Desktop\LAB-GEN AI\.venv\Lib\site-packages\pypdf\_reader.py:172, in PdfReader._initialize_stream(self, stream)
#     170 self._stream_opened = False
#     171 if isinstance(stream, (str, Path)):
# --> 172     with open(stream, "rb") as fh:
#     173         stream = BytesIO(fh.read())
#     174     self._stream_opened = True
#
# FileNotFoundError: [Errno 2] No such file or directory: ''
